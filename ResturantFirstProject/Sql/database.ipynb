-- %% [markdown]
-- # [ResturantDB]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [ResturantDB]    Script Date: 9/23/2022 4:03:39 PM ******/
CREATE DATABASE [ResturantDB]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'ResturantDB', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\ResturantDB.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'ResturantDB_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\ResturantDB_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [ResturantDB] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [ResturantDB].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [ResturantDB] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [ResturantDB] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [ResturantDB] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [ResturantDB] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [ResturantDB] SET ARITHABORT OFF 
GO
ALTER DATABASE [ResturantDB] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [ResturantDB] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [ResturantDB] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [ResturantDB] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [ResturantDB] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [ResturantDB] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [ResturantDB] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [ResturantDB] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [ResturantDB] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [ResturantDB] SET  DISABLE_BROKER 
GO
ALTER DATABASE [ResturantDB] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [ResturantDB] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [ResturantDB] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [ResturantDB] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [ResturantDB] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [ResturantDB] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [ResturantDB] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [ResturantDB] SET RECOVERY FULL 
GO
ALTER DATABASE [ResturantDB] SET  MULTI_USER 
GO
ALTER DATABASE [ResturantDB] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [ResturantDB] SET DB_CHAINING OFF 
GO
ALTER DATABASE [ResturantDB] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [ResturantDB] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [ResturantDB] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [ResturantDB] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'ResturantDB', N'ON'
GO
ALTER DATABASE [ResturantDB] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[Restaurants]

-- %%
USE [ResturantDB]
GO

-- %%
/****** Object:  Table [dbo].[Restaurants]    Script Date: 9/23/2022 4:03:40 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Restaurants](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Name] [varchar](255) NOT NULL,
	[PhoneNumber] [varchar](255) NOT NULL,
	[CreatedAt] [date] NULL,
	[UpdatedAt] [date] NULL,
	[Archived] [bit] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[RestaurantMenus]

-- %%
/****** Object:  Table [dbo].[RestaurantMenus]    Script Date: 9/23/2022 4:03:40 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[RestaurantMenus](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[mealName] [varchar](255) NOT NULL,
	[Archived] [bit] NOT NULL,
	[CreatedAt] [date] NULL,
	[UpdatedAt] [date] NULL,
	[PricieInNIS] [float] NOT NULL,
	[PriceInUsd] [float] NOT NULL,
	[Quantity] [int] NOT NULL,
	[IdRestaurant] [int] NOT NULL,
 CONSTRAINT [PK__Restaura__3214EC07D213A314] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Customers]

-- %%
/****** Object:  Table [dbo].[Customers]    Script Date: 9/23/2022 4:03:40 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Customers](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Archived] [bit] NOT NULL,
	[CreatedAt] [date] NULL,
	[UpdatedAt] [date] NULL,
	[FirstName] [varchar](255) NOT NULL,
	[LastName] [varchar](255) NOT NULL,
 CONSTRAINT [PK__Customer__3214EC078F7F76C4] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Orders]

-- %%
/****** Object:  Table [dbo].[Orders]    Script Date: 9/23/2022 4:03:40 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Orders](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[OrderName] [varchar](255) NOT NULL,
	[IdResturantMenu] [int] NOT NULL,
	[IdCustomer] [int] NOT NULL,
	[CreatedAt] [date] NULL,
	[UpdatedAt] [date] NULL,
	[Archived] [bit] NOT NULL,
	[TotalPrice] [float] NOT NULL,
	[Quantity] [int] NOT NULL,
 CONSTRAINT [PK__Orders__3214EC073F3CF70A] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ReportResturant]

-- %%
/****** Object:  View [dbo].[ReportResturant]    Script Date: 9/23/2022 4:03:40 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--create view ReportNew as
--(

--)

--SELECT        TOP (5)  CONCAT_WS(' ',dbo.Customers.FirstName, dbo.Customers.LastName) as MostPurchasedCustomer , COUNT(dbo.Orders.Id) AS NumberOfOrderedCustomer, dbo.RestaurantMenus.mealName  AS TheBestSellingMeal, SUM(dbo.RestaurantMenus.PricieInNIS) AS PricieInNIS, 
--                         SUM(dbo.RestaurantMenus.PriceInUsd) as PriceInUsd, dbo.Restaurants.Name AS RestaurantName
--FROM            dbo.Orders INNER JOIN
--                         dbo.Customers ON dbo.Orders.IdCustomer = dbo.Customers.Id  JOIN
--                         dbo.RestaurantMenus ON dbo.Orders.IdResturantMenu = dbo.RestaurantMenus.Id  JOIN
--                         dbo.Restaurants ON dbo.RestaurantMenus.IdRestaurant = dbo.Restaurants.Id

--GROUP BY dbo.Customers.FirstName, dbo.Customers.LastName, dbo.RestaurantMenus.mealName, PriceInUsd, PriceInUsd, dbo.Restaurants.Name

Create view [dbo].[ReportResturant] as
(

select * from
(select *, Rank()over(order by total_orders desc) as Rank_ from
(select sum(PriceInUsd) as PriceInUsd,sum(PricieInNIS) as PricieInNIS , Restaurants.Name as RestuarntName
,CONCAT_WS(' ',Customers.FirstName, Customers.LastName) as TheMostPurchasedCustomer,Restaurants.Id as resturantId, count(Restaurants.Id) as total_orders

from Orders join
Customers on Orders.IdCustomer = Customers.Id join
RestaurantMenus on Orders.IdResturantMenu = RestaurantMenus.Id join
Restaurants on RestaurantMenus.IdRestaurant = Restaurants.Id
group by Restaurants.Name,Restaurants.Id, Customers.FirstName, Customers.LastName, IdCustomer)AA)BB

)


GO

-- %% [markdown]
-- # [DF__Customers__Archi__2D27B809]

-- %%
ALTER TABLE [dbo].[Customers] ADD  CONSTRAINT [DF__Customers__Archi__2D27B809]  DEFAULT ((0)) FOR [Archived]
GO

-- %% [markdown]
-- # [DF__Customers__Creat__2E1BDC42]

-- %%
ALTER TABLE [dbo].[Customers] ADD  CONSTRAINT [DF__Customers__Creat__2E1BDC42]  DEFAULT (getdate()) FOR [CreatedAt]
GO

-- %% [markdown]
-- # [DF__Orders__CreatedA__30F848ED]

-- %%
ALTER TABLE [dbo].[Orders] ADD  CONSTRAINT [DF__Orders__CreatedA__30F848ED]  DEFAULT (getdate()) FOR [CreatedAt]
GO

-- %% [markdown]
-- # [DF__Orders__Archived__31EC6D26]

-- %%
ALTER TABLE [dbo].[Orders] ADD  CONSTRAINT [DF__Orders__Archived__31EC6D26]  DEFAULT ((0)) FOR [Archived]
GO

-- %% [markdown]
-- # [DF__Restauran__Archi__286302EC]

-- %%
ALTER TABLE [dbo].[RestaurantMenus] ADD  CONSTRAINT [DF__Restauran__Archi__286302EC]  DEFAULT ((0)) FOR [Archived]
GO

-- %% [markdown]
-- # [DF__Restauran__Creat__29572725]

-- %%
ALTER TABLE [dbo].[RestaurantMenus] ADD  CONSTRAINT [DF__Restauran__Creat__29572725]  DEFAULT (getdate()) FOR [CreatedAt]
GO

-- %% [markdown]
-- # [DF__Restauran__Creat__24927208]

-- %%
ALTER TABLE [dbo].[Restaurants] ADD  DEFAULT (getdate()) FOR [CreatedAt]
GO

-- %% [markdown]
-- # [DF__Restauran__Archi__25869641]

-- %%
ALTER TABLE [dbo].[Restaurants] ADD  DEFAULT ((0)) FOR [Archived]
GO

-- %% [markdown]
-- # [FK__Orders__IdCustom__33D4B598]

-- %%
ALTER TABLE [dbo].[Orders]  WITH CHECK ADD  CONSTRAINT [FK__Orders__IdCustom__33D4B598] FOREIGN KEY([IdCustomer])
REFERENCES [dbo].[Customers] ([Id])
GO
ALTER TABLE [dbo].[Orders] CHECK CONSTRAINT [FK__Orders__IdCustom__33D4B598]
GO

-- %% [markdown]
-- # [FK__Orders__IdRestur__32E0915F]

-- %%
ALTER TABLE [dbo].[Orders]  WITH CHECK ADD  CONSTRAINT [FK__Orders__IdRestur__32E0915F] FOREIGN KEY([IdResturantMenu])
REFERENCES [dbo].[RestaurantMenus] ([Id])
GO
ALTER TABLE [dbo].[Orders] CHECK CONSTRAINT [FK__Orders__IdRestur__32E0915F]
GO

-- %% [markdown]
-- # [FK__Restauran__IdRes__2A4B4B5E]

-- %%
ALTER TABLE [dbo].[RestaurantMenus]  WITH CHECK ADD  CONSTRAINT [FK__Restauran__IdRes__2A4B4B5E] FOREIGN KEY([IdRestaurant])
REFERENCES [dbo].[Restaurants] ([Id])
GO
ALTER TABLE [dbo].[RestaurantMenus] CHECK CONSTRAINT [FK__Restauran__IdRes__2A4B4B5E]
GO

-- %% [markdown]
-- # [ResturantDB]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [ResturantDB] SET  READ_WRITE 
GO
